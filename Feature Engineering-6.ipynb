# %% [markdown]
# # Q1. Pearson Correlation Coefficient:
# The Pearson correlation coefficient measures the linear relationship between two variables. It ranges from -1 to +1, where:
#
# +1 indicates a perfect positive linear relationship,
# -1 indicates a perfect negative linear relationship, and
# 0 indicates no linear relationship.
#
# To calculate the Pearson correlation coefficient between the time students spend studying and their final exam scores, you'd follow these steps:
#
# Collect the data (e.g., hours of study and exam scores).
# Calculate the sum of the products of the paired values (xy).
#
# Interpretation:
#
# If the result is close to +1, it indicates that as study time increases, the exam scores tend to increase.
# If the result is close to -1, it suggests an inverse relationship (more study time corresponds to lower scores).
# A result near 0 implies no linear relationship.
#
#
# # Q2. Spearman's Rank Correlation:
# Spearman's rank correlation measures the monotonic relationship between two variables. Unlike Pearson, it does not require the data to be linearly related and can capture both increasing and decreasing relationships.
#
# Steps:
#
# Rank the data for both variables.
#
# Calculate the difference in ranks for each pair of values.
#
# Square these differences and sum them.
#
# Apply the formula to calculate
#
# Interpretation:
#
# A value close to +1 indicates a strong positive monotonic relationship (as one variable increases, so does the other).
# A value close to -1 indicates a strong negative monotonic relationship (as one variable increases, the other decreases).
# A value near 0 indicates no monotonic relationship.
#
#
# # Q3. Comparing Pearson and Spearman Correlation:
# To calculate both the Pearson correlation coefficient and Spearman's rank correlation for the number of hours of exercise and BMI in a sample of 50 participants, you'd follow these steps:
#
# Pearson measures the linear relationship between the two variables.
# Spearman measures the monotonic relationship, which can be either linear or non-linear but must consistently increase or decrease.
# Steps:
#
# Calculate Pearson's correlation by applying the formula mentioned above.
# Rank the values for both variables and apply the Spearman rank correlation formula.
# Interpretation:
#
# Compare the two values. If both correlations are similar and close to +1 or -1, then a strong linear or monotonic relationship exists.
# If Pearson shows a high correlation but Spearman does not (or vice versa), it suggests that there may be a non-monotonic but linear relationship, or a weak monotonic relationship despite a clear linear one.
#
#
# # Q4. Pearson Correlation for TV Watching vs. Physical Activity:
# To calculate the Pearson correlation coefficient between the number of hours spent watching television and physical activity levels, you will:
#
# Collect the data (e.g., TV watching hours and physical activity).
#
# Apply the Pearson formula.
#
# Interpretation:
#
# If the result is close to +1, it indicates that more TV watching correlates with more physical activity.
# If close to -1, more TV watching is linked to less physical activity.
# A result near 0 suggests no significant linear relationship.
#
# # Q5. Survey Data on Age vs. Soft Drink Preference:
# For the relationship between Age and preference for a brand of soft drink, you would:
#
# Gather the data on age and soft drink preference (perhaps coded numerically).
# Use Pearson correlation if you believe there is a linear relationship or Spearman if the relationship may be monotonic but not linear.
# Interpretation:
#
# Pearson will show if there's a linear correlation between age and preference.
# Spearman will show if there's a monotonic relationship (whether the relationship is consistent but not necessarily linear).
#
#
# # Q6. Pearson Correlation for Sales Calls vs. Sales Made:
# To calculate the Pearson correlation coefficient between the number of sales calls made per day and the number of sales made per week for 30 sales representatives, you'd:
#
# Gather the data (sales calls and sales made).
#
# Interpretation:
#
# A high positive Pearson value indicates that making more calls correlates with more sales.
# A value close to 0 indicates no linear relationship.
# A negative value suggests that making more calls could inversely relate to the number of sales made.
#
#
# Interpretation of Python Output:
# The output will provide you with the Pearson and Spearman correlation coefficients.
# Pearson is typically used when you expect a linear relationship, and Spearman is used when you suspect a monotonic relationship but not necessarily linear.
